# %%
include("tests-collisions3d.jl")
# Out:
# compare_lorentz3d (generic function with 1 method)

# %%
compare_lorentz3d(x, v, r, 100, 64)
# Out:
# (x1,y1) = first(Pxy(x),v_xy,r) => BigInt[1,1]
# (y2,z2) = first(Pyz(x),v_yz,r) =>
# BigInt[2,1]
# (x3,z3) = first(Pxz(x),v_xz,r) => BigInt[2,1]
# possible_hit && approx(time_xy,time_yz,0.5) && approx(time_xz,time_yz,0.5) => true
# x_new != false => true
# push!(places,ball) => [BigInt[2,2,1]]
# push!(coords,x) => [BigFloat[1.86388978276529009557e+00,1.87018040234950435349e+00,9.32022938941261145426e-01]]
# push!(speeds,v) => [BigFloat[-6.95301102766206562253e-01,-6.29096185054838065367e-01,-3.47554839473637600025e-01]]
# steps += 1 => 2
# (x1,y1) = first(Pxy(x),v_xy,r) => BigInt[1,1]
# (y2,z2) = first(Pyz(x),v_yz,r) => BigInt[0,0]
# (x3,z3) = first(Pxz(x),v_xz,r) => BigInt[0,0]
# possible_hit && approx(time_xy,time_yz,0.5) && approx(time_xz,time_yz,0.5) => true
# x_new != false => true
# push!(places,ball) => [BigInt[2,2,1],BigInt[0,0,0]]
# ...
